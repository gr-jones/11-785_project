# %%
# !pip3 install -q idx2numpy
# !pip3 install -q --upgrade --force-reinstall matplotlib
# Out:
# ERROR: tensorflow 2.3.0 has requirement numpy<1.19.0,>=1.16.0, but you'll have numpy 1.19.4 which is incompatible.
# ERROR: nbclient 0.5.1 has requirement jupyter-client>=6.1.5, but you'll have jupyter-client 5.3.5 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.

# %% [markdown]
# ### Import libraries

# %%
import argparse, torch, random
import numpy as np
from torchvision import datasets, transforms
import torch.nn.functional as F
from models import SNN, SpikeCELoss

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
from torch.autograd import Function

import idx2numpy
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### WrapperFunction Class

# %%
class WrapperFunction(Function):
    @staticmethod
    def forward(ctx, input, params, forward, backward):
        ctx.backward = backward
        pack, output = forward(input)
        ctx.save_for_backward(*pack)
        return output

    @staticmethod
    def backward(ctx, grad_output):
        backward = ctx.backward
        pack = ctx.saved_tensors
        grad_input, grad_weight = backward(grad_output, *pack)
        return grad_input, grad_weight, None, None

# %% [markdown]
# ### FirstSpikeTime Class

# %%
class FirstSpikeTime(Function):
    @staticmethod
    def forward(ctx, input):   
        idx = torch.arange(input.shape[2], 0, -1).unsqueeze(0).unsqueeze(0).float().cuda()
        first_spike_times = torch.argmax(idx*input, dim=2).float()
        ctx.save_for_backward(input, first_spike_times.clone())
        first_spike_times[first_spike_times==0] = input.shape[2]-1
        return first_spike_times
    
    @staticmethod
    def backward(ctx, grad_output):
        input, first_spike_times = ctx.saved_tensors
        k = F.one_hot(first_spike_times.long(), input.shape[2]).float()
        grad_input = k * grad_output.unsqueeze(-1)
        return grad_input

# %% [markdown]
# ### SpikingLinear Class

# %%
class SpikingLinear(nn.Module):
    def __init__(self, input_dim, output_dim, T, dt, tau_m, tau_s, mu):
        super(SpikingLinear, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.T = T
        self.dt = dt
        self.tau_m = tau_m
        self.tau_s = tau_s
        
        self.weight = nn.Parameter(torch.Tensor(output_dim, input_dim))
        nn.init.normal_(self.weight, mu, mu)
        
        self.forward = lambda input : WrapperFunction.apply(input, self.weight, self.manual_forward, self.manual_backward)
        
    def manual_forward(self, input):
        steps = int(self.T / self.dt)
    
        V = torch.zeros(input.shape[0], self.output_dim, steps).cuda()
        I = torch.zeros(input.shape[0], self.output_dim, steps).cuda()
        output = torch.zeros(input.shape[0], self.output_dim, steps).cuda()

        while True:
            for i in range(1, steps):
                t = i * self.dt
                V[:,:,i] = (1 - self.dt / self.tau_m) * V[:,:,i-1] + (self.dt / self.tau_m) * I[:,:,i-1]
                I[:,:,i] = (1 - self.dt / self.tau_s) * I[:,:,i-1] + F.linear(input[:,:,i-1].float(), self.weight)
                spikes = (V[:,:,i] > 1.0).float()
                output[:,:,i] = spikes
                V[:,:,i] = (1-spikes) * V[:,:,i]

            if self.training:
                is_silent = output.sum(2).min(0)[0] == 0
                self.weight.data[is_silent] = self.weight.data[is_silent] + 1e-1
                if is_silent.sum() == 0:
                    break
            else:
                break

        return (input, I, output), output
    
    def manual_backward(self, grad_output, input, I, post_spikes):
        steps = int(self.T / self.dt)
                
        lV = torch.zeros(input.shape[0], self.output_dim, steps).cuda()
        lI = torch.zeros(input.shape[0], self.output_dim, steps).cuda()
        
        grad_input = torch.zeros(input.shape[0], input.shape[1], steps).cuda()
        grad_weight = torch.zeros(input.shape[0], *self.weight.shape).cuda()
        
        for i in range(steps-2, -1, -1):
            t = i * self.dt
            delta = lV[:,:,i+1] - lI[:,:,i+1]
            grad_input[:,:,i] = F.linear(delta, self.weight.t())
            lV[:,:,i] = (1 - self.dt / self.tau_m) * lV[:,:,i+1] + post_spikes[:,:,i+1] * (lV[:,:,i+1] + grad_output[:,:,i+1]) / (I[:,:,i] - 1 + 1e-10)
            lI[:,:,i] = lI[:,:,i+1] + (self.dt / self.tau_s) * (lV[:,:,i+1] - lI[:,:,i+1])
            spike_bool = input[:,:,i].float()
            grad_weight -= (spike_bool.unsqueeze(1) * lI[:,:,i].unsqueeze(2))

        return grad_input, grad_weight

# %% [markdown]
# ### SNN Class

# %%
class SNN(nn.Module):
    def __init__(self, input_dim, output_dim, T, dt, tau_m, tau_s):
        super(SNN, self).__init__()
        self.slinear1 = SpikingLinear(input_dim, 10, T, dt, tau_m, tau_s, 0.1)
        self.outact = FirstSpikeTime.apply
        
    def forward(self, input):
        u = self.slinear1(input)
        u = self.outact(u)
        return u

# %% [markdown]
# ### SpikeCELoss Class

# %%
class SpikeCELoss(nn.Module):
    def __init__(self, T, xi, tau_s):
        super(SpikeCELoss, self).__init__()
        self.xi = xi
        self.tau_s = tau_s
        self.celoss = nn.CrossEntropyLoss()
        
    def forward(self, input, target):
        loss = self.celoss(-input / (self.xi * self.tau_s), target)
        return loss

# %% [markdown]
# ### Download data

# %%
# !wget -q -r -A '*ubyte.gz' --no-parent  'http://yann.lecun.com/exdb/mnist/'
# !rm -rf data
# !mkdir data
# !mv yann.lecun.com/exdb/mnist/* data/
# !rm -rf yann.lecun.com
# !gunzip data/*

# %%
data_folder = '/content/data/'
device = 'cuda'
# seed thing
print_freq = 100
deterministic = True

# Training settings
num_epochs = 100
lr = 1.0
batch_size = 128

# Loss settings (specific for SNNs)
xi = 0.4
alpha = 1e-2
beta = 2.0

# Spiking Model settings
T = 20
dt = 1
tau_m = 20
tau_s = 5
t_max = 12
t_min = 2

# %% [markdown]
# ### New Section

# %%
if deterministic:
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %% [markdown]
# ### Encode data method

# %%
def encode_data(data):
    spike_data = t_min + (t_max - t_min) * (data < 0.5).view(data.shape[0], -1)
    spike_data = F.one_hot(spike_data.long(), int(T))
    return spike_data

# %% [markdown]
# ### Train method

# %%
def train(model, criterion, optimizer, loader):
    total_correct = 0.
    total_loss = 0.
    total_samples = 0.
    model.train()
    
    for batch_idx, (input, target) in enumerate(loader):
        input, target = input.to(device), target.to(device)
        input = encode_data(input)
        
        total_correct = 0.
        total_loss = 0.
        total_samples = 0.
        
        output = model(input)

        loss = criterion(output, target)

        if alpha != 0:
            target_first_spike_times = output.gather(1, target.view(-1, 1))
            loss += alpha * (torch.exp(target_first_spike_times / (beta * tau_s)) - 1).mean()

        predictions = output.data.min(1, keepdim=True)[1]
        total_correct += predictions.eq(target.data.view_as(predictions)).sum().item()
        total_loss += loss.item() * len(target)
        total_samples += len(target)
        
        optimizer.zero_grad()
        loss.backward()
        
        optimizer.step()

        if batch_idx % print_freq == 0:
            print('\tBatch {:03d}/{:03d}: \tAcc {:.2f}  Loss {:.3f}'.format(batch_idx, len(loader), 100*total_correct/total_samples, total_loss/total_samples))
   
    print('\t\tTrain: \tAcc {:.2f}  Loss {:.3f}'.format(100*total_correct/total_samples, total_loss/total_samples))

# %% [markdown]
# ### Test method

# %%
def test(model, loader):
    total_correct = 0.
    total_samples = 0.
    model.eval()
    
    with torch.no_grad():
        for batch_idx, (data, target) in enumerate(loader):
            data, target = data.to(device), target.to(device)
            spike_data = encode_data(data)
            
            first_post_spikes = model(spike_data)
            predictions = first_post_spikes.data.min(1, keepdim=True)[1]
            total_correct += predictions.eq(target.data.view_as(predictions)).sum().item()
            total_samples += len(target)
            
        print('\t\tTest: \tAcc {:.2f}'.format(100*total_correct/total_samples))

# %% [markdown]
# ### Create dataset and loader objects

# %%
train_dataset = datasets.MNIST(data_folder, train=True, download=True, transform=transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

test_dataset = datasets.MNIST(data_folder, train=False, download=True, transform=transforms.ToTensor())
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
        
model = SNN(784, 10, T, dt, tau_m, tau_s).to(device)
criterion = SpikeCELoss(T, xi, tau_s)
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /content/data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /content/data/MNIST/raw/train-images-idx3-ubyte.gz to /content/data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /content/data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /content/data/MNIST/raw/train-labels-idx1-ubyte.gz to /content/data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /content/data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /content/data/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /content/data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting /content/data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/data/MNIST/raw
# Processing...
# Done!

# %% [markdown]
# ### Epoch training

# %%
for epoch in range(num_epochs):
    print('Epoch {:03d}/{:03d}'.format(epoch, num_epochs))
    train(model, criterion, optimizer, train_loader)
    test(model, test_loader)
    scheduler.step()
# Out:
# Epoch 000/100
# 	Batch 000/469: 	Acc 9.38  Loss 2.440
# 	Batch 100/469: 	Acc 50.78  Loss 1.344
# 	Batch 200/469: 	Acc 75.78  Loss 1.060
# 	Batch 300/469: 	Acc 69.53  Loss 0.848
# 	Batch 400/469: 	Acc 82.03  Loss 0.716
# 		Train: 	Acc 69.79  Loss 1.049
# 		Test: 	Acc 69.97
# Epoch 001/100
# 	Batch 000/469: 	Acc 71.09  Loss 0.924
# 	Batch 100/469: 	Acc 80.47  Loss 0.684
# 	Batch 200/469: 	Acc 84.38  Loss 0.593
# 	Batch 300/469: 	Acc 82.81  Loss 0.618
# 	Batch 400/469: 	Acc 87.50  Loss 0.527
# 		Train: 	Acc 81.25  Loss 0.537
# 		Test: 	Acc 83.18
# Epoch 002/100
# 	Batch 000/469: 	Acc 85.16  Loss 0.591
# 	Batch 100/469: 	Acc 78.91  Loss 0.838
# 	Batch 200/469: 	Acc 86.72  Loss 0.427
# 	Batch 300/469: 	Acc 80.47  Loss 0.693
# 	Batch 400/469: 	Acc 82.81  Loss 0.579
# 		Train: 	Acc 82.29  Loss 0.679
# 		Test: 	Acc 84.56
# Epoch 003/100
# 	Batch 000/469: 	Acc 84.38  Loss 0.597
# 	Batch 100/469: 	Acc 85.16  Loss 0.511
# 	Batch 200/469: 	Acc 87.50  Loss 0.408
# 	Batch 300/469: 	Acc 86.72  Loss 0.479
# 	Batch 400/469: 	Acc 84.38  Loss 0.626
# 		Train: 	Acc 84.38  Loss 0.574
# 		Test: 	Acc 86.83
# Epoch 004/100
# 	Batch 000/469: 	Acc 84.38  Loss 0.538
# 	Batch 100/469: 	Acc 89.06  Loss 0.519
# 	Batch 200/469: 	Acc 87.50  Loss 0.484
# 	Batch 300/469: 	Acc 73.44  Loss 0.754
# 	Batch 400/469: 	Acc 84.38  Loss 0.541
# 		Train: 	Acc 84.38  Loss 0.547
# 		Test: 	Acc 86.90
# Epoch 005/100
# 	Batch 000/469: 	Acc 92.19  Loss 0.348
# 	Batch 100/469: 	Acc 88.28  Loss 0.449
# 	Batch 200/469: 	Acc 81.25  Loss 0.614
# 	Batch 300/469: 	Acc 91.41  Loss 0.405
# 	Batch 400/469: 	Acc 86.72  Loss 0.549
# 		Train: 	Acc 81.25  Loss 0.759
# 		Test: 	Acc 72.19
# Epoch 006/100
# 	Batch 000/469: 	Acc 63.28  Loss 1.040
# 	Batch 100/469: 	Acc 88.28  Loss 0.495
# 	Batch 200/469: 	Acc 84.38  Loss 0.511
# 	Batch 300/469: 	Acc 88.28  Loss 0.428
# 	Batch 400/469: 	Acc 89.06  Loss 0.440
# 		Train: 	Acc 80.21  Loss 0.742
# 		Test: 	Acc 87.29
# Epoch 007/100
# 	Batch 000/469: 	Acc 82.03  Loss 0.552
# 	Batch 100/469: 	Acc 87.50  Loss 0.444
# 	Batch 200/469: 	Acc 84.38  Loss 0.609
# 	Batch 300/469: 	Acc 77.34  Loss 0.689
# 	Batch 400/469: 	Acc 91.41  Loss 0.350
# 		Train: 	Acc 90.62  Loss 0.389
# 		Test: 	Acc 86.38
# Epoch 008/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.452
# 	Batch 100/469: 	Acc 85.94  Loss 0.538
# 	Batch 200/469: 	Acc 85.94  Loss 0.472
# 	Batch 300/469: 	Acc 86.72  Loss 0.536
# 	Batch 400/469: 	Acc 86.72  Loss 0.494
# 		Train: 	Acc 91.67  Loss 0.412
# 		Test: 	Acc 87.66
# Epoch 009/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.541
# 	Batch 100/469: 	Acc 82.81  Loss 0.539
# 	Batch 200/469: 	Acc 85.94  Loss 0.524
# 	Batch 300/469: 	Acc 85.16  Loss 0.638
# 	Batch 400/469: 	Acc 91.41  Loss 0.382
# 		Train: 	Acc 91.67  Loss 0.330
# 		Test: 	Acc 87.67
# Epoch 010/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.482
# 	Batch 100/469: 	Acc 86.72  Loss 0.524
# 	Batch 200/469: 	Acc 81.25  Loss 0.689
# 	Batch 300/469: 	Acc 85.16  Loss 0.467
# 	Batch 400/469: 	Acc 85.16  Loss 0.571
# 		Train: 	Acc 82.29  Loss 0.584
# 		Test: 	Acc 87.89
# Epoch 011/100
# 	Batch 000/469: 	Acc 89.84  Loss 0.407
# 	Batch 100/469: 	Acc 92.19  Loss 0.327
# 	Batch 200/469: 	Acc 84.38  Loss 0.569
# 	Batch 300/469: 	Acc 80.47  Loss 0.597
# 	Batch 400/469: 	Acc 81.25  Loss 0.663
# 		Train: 	Acc 92.71  Loss 0.316
# 		Test: 	Acc 87.79
# Epoch 012/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.515
# 	Batch 100/469: 	Acc 88.28  Loss 0.443
# 	Batch 200/469: 	Acc 88.28  Loss 0.402
# 	Batch 300/469: 	Acc 87.50  Loss 0.426
# 	Batch 400/469: 	Acc 88.28  Loss 0.428
# 		Train: 	Acc 94.79  Loss 0.294
# 		Test: 	Acc 88.10
# Epoch 013/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.437
# 	Batch 100/469: 	Acc 91.41  Loss 0.334
# 	Batch 200/469: 	Acc 82.81  Loss 0.640
# 	Batch 300/469: 	Acc 86.72  Loss 0.463
# 	Batch 400/469: 	Acc 88.28  Loss 0.488
# 		Train: 	Acc 87.50  Loss 0.480
# 		Test: 	Acc 88.12
# Epoch 014/100
# 	Batch 000/469: 	Acc 92.97  Loss 0.347
# 	Batch 100/469: 	Acc 88.28  Loss 0.443
# 	Batch 200/469: 	Acc 89.06  Loss 0.424
# 	Batch 300/469: 	Acc 84.38  Loss 0.489
# 	Batch 400/469: 	Acc 82.03  Loss 0.572
# 		Train: 	Acc 92.71  Loss 0.311
# 		Test: 	Acc 88.41
# Epoch 015/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.516
# 	Batch 100/469: 	Acc 92.97  Loss 0.304
# 	Batch 200/469: 	Acc 86.72  Loss 0.469
# 	Batch 300/469: 	Acc 89.84  Loss 0.431
# 	Batch 400/469: 	Acc 88.28  Loss 0.429
# 		Train: 	Acc 85.42  Loss 0.524
# 		Test: 	Acc 88.01
# Epoch 016/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.519
# 	Batch 100/469: 	Acc 86.72  Loss 0.445
# 	Batch 200/469: 	Acc 85.94  Loss 0.462
# 	Batch 300/469: 	Acc 90.62  Loss 0.380
# 	Batch 400/469: 	Acc 89.84  Loss 0.360
# 		Train: 	Acc 90.62  Loss 0.393
# 		Test: 	Acc 88.18
# Epoch 017/100
# 	Batch 000/469: 	Acc 85.16  Loss 0.490
# 	Batch 100/469: 	Acc 91.41  Loss 0.398
# 	Batch 200/469: 	Acc 82.03  Loss 0.699
# 	Batch 300/469: 	Acc 90.62  Loss 0.371
# 	Batch 400/469: 	Acc 89.84  Loss 0.415
# 		Train: 	Acc 86.46  Loss 0.468
# 		Test: 	Acc 88.41
# Epoch 018/100
# 	Batch 000/469: 	Acc 90.62  Loss 0.378
# 	Batch 100/469: 	Acc 89.84  Loss 0.388
# 	Batch 200/469: 	Acc 89.84  Loss 0.486
# 	Batch 300/469: 	Acc 92.19  Loss 0.324
# 	Batch 400/469: 	Acc 90.62  Loss 0.383
# 		Train: 	Acc 86.46  Loss 0.451
# 		Test: 	Acc 88.31
# Epoch 019/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.507
# 	Batch 100/469: 	Acc 90.62  Loss 0.384
# 	Batch 200/469: 	Acc 87.50  Loss 0.461
# 	Batch 300/469: 	Acc 88.28  Loss 0.463
# 	Batch 400/469: 	Acc 91.41  Loss 0.366
# 		Train: 	Acc 90.62  Loss 0.373
# 		Test: 	Acc 87.94
# Epoch 020/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.427
# 	Batch 100/469: 	Acc 89.06  Loss 0.431
# 	Batch 200/469: 	Acc 89.06  Loss 0.390
# 	Batch 300/469: 	Acc 89.84  Loss 0.433
# 	Batch 400/469: 	Acc 90.62  Loss 0.346
# 		Train: 	Acc 85.42  Loss 0.472
# 		Test: 	Acc 87.99
# Epoch 021/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.403
# 	Batch 100/469: 	Acc 86.72  Loss 0.495
# 	Batch 200/469: 	Acc 89.06  Loss 0.482
# 	Batch 300/469: 	Acc 90.62  Loss 0.366
# 	Batch 400/469: 	Acc 89.06  Loss 0.522
# 		Train: 	Acc 90.62  Loss 0.403
# 		Test: 	Acc 88.04
# Epoch 022/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.403
# 	Batch 100/469: 	Acc 91.41  Loss 0.341
# 	Batch 200/469: 	Acc 87.50  Loss 0.443
# 	Batch 300/469: 	Acc 89.06  Loss 0.407
# 	Batch 400/469: 	Acc 92.97  Loss 0.287
# 		Train: 	Acc 85.42  Loss 0.526
# 		Test: 	Acc 88.08
# Epoch 023/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.498
# 	Batch 100/469: 	Acc 89.84  Loss 0.368
# 	Batch 200/469: 	Acc 89.84  Loss 0.397
# 	Batch 300/469: 	Acc 93.75  Loss 0.255
# 	Batch 400/469: 	Acc 89.84  Loss 0.388
# 		Train: 	Acc 93.75  Loss 0.259
# 		Test: 	Acc 88.08
# Epoch 024/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.406
# 	Batch 100/469: 	Acc 82.81  Loss 0.484
# 	Batch 200/469: 	Acc 90.62  Loss 0.354
# 	Batch 300/469: 	Acc 89.84  Loss 0.417
# 	Batch 400/469: 	Acc 85.94  Loss 0.483
# 		Train: 	Acc 92.71  Loss 0.349
# 		Test: 	Acc 88.06
# Epoch 025/100
# 	Batch 000/469: 	Acc 82.03  Loss 0.535
# 	Batch 100/469: 	Acc 84.38  Loss 0.523
# 	Batch 200/469: 	Acc 89.84  Loss 0.386
# 	Batch 300/469: 	Acc 89.06  Loss 0.410
# 	Batch 400/469: 	Acc 89.84  Loss 0.391
# 		Train: 	Acc 89.58  Loss 0.364
# 		Test: 	Acc 88.10
# Epoch 026/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.358
# 	Batch 100/469: 	Acc 89.84  Loss 0.371
# 	Batch 200/469: 	Acc 92.97  Loss 0.310
# 	Batch 300/469: 	Acc 82.81  Loss 0.640
# 	Batch 400/469: 	Acc 89.06  Loss 0.339
# 		Train: 	Acc 86.46  Loss 0.488
# 		Test: 	Acc 88.11
# Epoch 027/100
# 	Batch 000/469: 	Acc 85.16  Loss 0.527
# 	Batch 100/469: 	Acc 87.50  Loss 0.392
# 	Batch 200/469: 	Acc 89.84  Loss 0.358
# 	Batch 300/469: 	Acc 86.72  Loss 0.443
# 	Batch 400/469: 	Acc 89.84  Loss 0.368
# 		Train: 	Acc 89.58  Loss 0.404
# 		Test: 	Acc 88.16
# Epoch 028/100
# 	Batch 000/469: 	Acc 88.28  Loss 0.497
# 	Batch 100/469: 	Acc 89.06  Loss 0.466
# 	Batch 200/469: 	Acc 85.94  Loss 0.558
# 	Batch 300/469: 	Acc 87.50  Loss 0.389
# 	Batch 400/469: 	Acc 87.50  Loss 0.432
# 		Train: 	Acc 86.46  Loss 0.452
# 		Test: 	Acc 88.19
# Epoch 029/100
# 	Batch 000/469: 	Acc 93.75  Loss 0.366
# 	Batch 100/469: 	Acc 89.06  Loss 0.455
# 	Batch 200/469: 	Acc 85.16  Loss 0.553
# 	Batch 300/469: 	Acc 84.38  Loss 0.560
# 	Batch 400/469: 	Acc 90.62  Loss 0.444
# 		Train: 	Acc 88.54  Loss 0.453
# 		Test: 	Acc 88.25
# Epoch 030/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.402
# 	Batch 100/469: 	Acc 88.28  Loss 0.414
# 	Batch 200/469: 	Acc 83.59  Loss 0.568
# 	Batch 300/469: 	Acc 87.50  Loss 0.472
# 	Batch 400/469: 	Acc 87.50  Loss 0.399
# 		Train: 	Acc 90.62  Loss 0.338
# 		Test: 	Acc 88.23
# Epoch 031/100
# 	Batch 000/469: 	Acc 86.72  Loss 0.527
# 	Batch 100/469: 	Acc 86.72  Loss 0.488
# 	Batch 200/469: 	Acc 87.50  Loss 0.422
# 	Batch 300/469: 	Acc 87.50  Loss 0.458
# 	Batch 400/469: 	Acc 86.72  Loss 0.524
# 		Train: 	Acc 87.50  Loss 0.378
# 		Test: 	Acc 88.24
# Epoch 032/100
# 	Batch 000/469: 	Acc 91.41  Loss 0.322
# 	Batch 100/469: 	Acc 85.94  Loss 0.521
# 	Batch 200/469: 	Acc 89.84  Loss 0.415
# 	Batch 300/469: 	Acc 86.72  Loss 0.475
# 	Batch 400/469: 	Acc 89.84  Loss 0.395
# 		Train: 	Acc 86.46  Loss 0.395
# 		Test: 	Acc 88.24
# Epoch 033/100
# 	Batch 000/469: 	Acc 86.72  Loss 0.421
# 	Batch 100/469: 	Acc 89.84  Loss 0.329
# 	Batch 200/469: 	Acc 87.50  Loss 0.424
# 	Batch 300/469: 	Acc 89.06  Loss 0.420
# 	Batch 400/469: 	Acc 85.94  Loss 0.494
# 		Train: 	Acc 87.50  Loss 0.454
# 		Test: 	Acc 88.27
# Epoch 034/100
# 	Batch 000/469: 	Acc 90.62  Loss 0.300
# 	Batch 100/469: 	Acc 85.16  Loss 0.470
# 	Batch 200/469: 	Acc 83.59  Loss 0.524
# 	Batch 300/469: 	Acc 89.06  Loss 0.380
# 	Batch 400/469: 	Acc 91.41  Loss 0.374
# 		Train: 	Acc 87.50  Loss 0.438
# 		Test: 	Acc 88.26
# Epoch 035/100
# 	Batch 000/469: 	Acc 90.62  Loss 0.316
# 	Batch 100/469: 	Acc 84.38  Loss 0.529
# 	Batch 200/469: 	Acc 90.62  Loss 0.326
# 	Batch 300/469: 	Acc 92.19  Loss 0.348
# 	Batch 400/469: 	Acc 87.50  Loss 0.521
# 		Train: 	Acc 85.42  Loss 0.465
# 		Test: 	Acc 88.27
# Epoch 036/100
# 	Batch 000/469: 	Acc 92.19  Loss 0.375
# 	Batch 100/469: 	Acc 84.38  Loss 0.559
# 	Batch 200/469: 	Acc 89.84  Loss 0.395
# 	Batch 300/469: 	Acc 87.50  Loss 0.452
# 	Batch 400/469: 	Acc 90.62  Loss 0.375
# 		Train: 	Acc 86.46  Loss 0.400
# 		Test: 	Acc 88.27
# Epoch 037/100
# 	Batch 000/469: 	Acc 86.72  Loss 0.418
# 	Batch 100/469: 	Acc 82.03  Loss 0.525
# 	Batch 200/469: 	Acc 86.72  Loss 0.443
# 	Batch 300/469: 	Acc 84.38  Loss 0.517
# 	Batch 400/469: 	Acc 90.62  Loss 0.345
# 		Train: 	Acc 90.62  Loss 0.346
# 		Test: 	Acc 88.26
# Epoch 038/100
# 	Batch 000/469: 	Acc 91.41  Loss 0.380
# 	Batch 100/469: 	Acc 81.25  Loss 0.581
# 	Batch 200/469: 	Acc 93.75  Loss 0.270
# 	Batch 300/469: 	Acc 85.16  Loss 0.502
# 	Batch 400/469: 	Acc 89.06  Loss 0.426
# 		Train: 	Acc 86.46  Loss 0.483
# 		Test: 	Acc 88.26
# Epoch 039/100
# 	Batch 000/469: 	Acc 90.62  Loss 0.327
# 	Batch 100/469: 	Acc 87.50  Loss 0.383
# 	Batch 200/469: 	Acc 86.72  Loss 0.403
# 	Batch 300/469: 	Acc 88.28  Loss 0.428
# 	Batch 400/469: 	Acc 88.28  Loss 0.405
# 		Train: 	Acc 89.58  Loss 0.445
# 		Test: 	Acc 88.26
# Epoch 040/100
# 	Batch 000/469: 	Acc 88.28  Loss 0.426
# 	Batch 100/469: 	Acc 87.50  Loss 0.506
# 	Batch 200/469: 	Acc 86.72  Loss 0.480
# 	Batch 300/469: 	Acc 92.97  Loss 0.309
# 	Batch 400/469: 	Acc 89.84  Loss 0.361
# 		Train: 	Acc 85.42  Loss 0.464
# 		Test: 	Acc 88.26
# Epoch 041/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.423
# 	Batch 100/469: 	Acc 89.06  Loss 0.402
# 	Batch 200/469: 	Acc 88.28  Loss 0.442
# 	Batch 300/469: 	Acc 86.72  Loss 0.502
# 	Batch 400/469: 	Acc 81.25  Loss 0.598
# 		Train: 	Acc 87.50  Loss 0.480
# 		Test: 	Acc 88.26
# Epoch 042/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.462
# 	Batch 100/469: 	Acc 93.75  Loss 0.272
# 	Batch 200/469: 	Acc 93.75  Loss 0.342
# 	Batch 300/469: 	Acc 87.50  Loss 0.422
# 	Batch 400/469: 	Acc 83.59  Loss 0.580
# 		Train: 	Acc 90.62  Loss 0.383
# 		Test: 	Acc 88.26
# Epoch 043/100
# 	Batch 000/469: 	Acc 86.72  Loss 0.511
# 	Batch 100/469: 	Acc 88.28  Loss 0.467
# 	Batch 200/469: 	Acc 86.72  Loss 0.460
# 	Batch 300/469: 	Acc 91.41  Loss 0.316
# 	Batch 400/469: 	Acc 92.19  Loss 0.325
# 		Train: 	Acc 88.54  Loss 0.581
# 		Test: 	Acc 88.27
# Epoch 044/100
# 	Batch 000/469: 	Acc 82.81  Loss 0.553
# 	Batch 100/469: 	Acc 91.41  Loss 0.268
# 	Batch 200/469: 	Acc 89.06  Loss 0.395
# 	Batch 300/469: 	Acc 89.84  Loss 0.360
# 	Batch 400/469: 	Acc 89.84  Loss 0.397
# 		Train: 	Acc 86.46  Loss 0.492
# 		Test: 	Acc 88.27
# Epoch 045/100
# 	Batch 000/469: 	Acc 82.03  Loss 0.586
# 	Batch 100/469: 	Acc 89.84  Loss 0.493
# 	Batch 200/469: 	Acc 85.94  Loss 0.466
# 	Batch 300/469: 	Acc 85.16  Loss 0.481
# 	Batch 400/469: 	Acc 87.50  Loss 0.361
# 		Train: 	Acc 90.62  Loss 0.324
# 		Test: 	Acc 88.27
# Epoch 046/100
# 	Batch 000/469: 	Acc 83.59  Loss 0.535
# 	Batch 100/469: 	Acc 90.62  Loss 0.384
# 	Batch 200/469: 	Acc 88.28  Loss 0.421
# 	Batch 300/469: 	Acc 87.50  Loss 0.482
# 	Batch 400/469: 	Acc 89.84  Loss 0.436
# 		Train: 	Acc 81.25  Loss 0.458
# 		Test: 	Acc 88.27
# Epoch 047/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.469
# 	Batch 100/469: 	Acc 83.59  Loss 0.522
# 	Batch 200/469: 	Acc 90.62  Loss 0.335
# 	Batch 300/469: 	Acc 88.28  Loss 0.446
# 	Batch 400/469: 	Acc 87.50  Loss 0.458
# 		Train: 	Acc 88.54  Loss 0.402
# 		Test: 	Acc 88.27
# Epoch 048/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.471
# 	Batch 100/469: 	Acc 88.28  Loss 0.456
# 	Batch 200/469: 	Acc 89.06  Loss 0.484
# 	Batch 300/469: 	Acc 83.59  Loss 0.547
# 	Batch 400/469: 	Acc 90.62  Loss 0.357
# 		Train: 	Acc 83.33  Loss 0.535
# 		Test: 	Acc 88.27
# Epoch 049/100
# 	Batch 000/469: 	Acc 91.41  Loss 0.364
# 	Batch 100/469: 	Acc 86.72  Loss 0.501
# 	Batch 200/469: 	Acc 89.84  Loss 0.365
# 	Batch 300/469: 	Acc 85.16  Loss 0.477
# 	Batch 400/469: 	Acc 87.50  Loss 0.415
# 		Train: 	Acc 89.58  Loss 0.436
# 		Test: 	Acc 88.27
# Epoch 050/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.451
# 	Batch 100/469: 	Acc 85.94  Loss 0.424
# 	Batch 200/469: 	Acc 92.19  Loss 0.291
# 	Batch 300/469: 	Acc 86.72  Loss 0.507
# 	Batch 400/469: 	Acc 90.62  Loss 0.354
# 		Train: 	Acc 90.62  Loss 0.414
# 		Test: 	Acc 88.27
# Epoch 051/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.439
# 	Batch 100/469: 	Acc 91.41  Loss 0.342
# 	Batch 200/469: 	Acc 84.38  Loss 0.470
# 	Batch 300/469: 	Acc 84.38  Loss 0.462
# 	Batch 400/469: 	Acc 87.50  Loss 0.437
# 		Train: 	Acc 87.50  Loss 0.458
# 		Test: 	Acc 88.27
# Epoch 052/100
# 	Batch 000/469: 	Acc 89.84  Loss 0.420
# 	Batch 100/469: 	Acc 89.06  Loss 0.347
# 	Batch 200/469: 	Acc 87.50  Loss 0.391
# 	Batch 300/469: 	Acc 89.06  Loss 0.431
# 	Batch 400/469: 	Acc 82.81  Loss 0.531
# 		Train: 	Acc 79.17  Loss 0.612
# 		Test: 	Acc 88.27
# Epoch 053/100
# 	Batch 000/469: 	Acc 89.84  Loss 0.415
# 	Batch 100/469: 	Acc 85.94  Loss 0.507
# 	Batch 200/469: 	Acc 85.94  Loss 0.439
# 	Batch 300/469: 	Acc 84.38  Loss 0.457
# 	Batch 400/469: 	Acc 85.94  Loss 0.496
# 		Train: 	Acc 91.67  Loss 0.349
# 		Test: 	Acc 88.27
# Epoch 054/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.452
# 	Batch 100/469: 	Acc 89.06  Loss 0.366
# 	Batch 200/469: 	Acc 87.50  Loss 0.515
# 	Batch 300/469: 	Acc 82.81  Loss 0.640
# 	Batch 400/469: 	Acc 84.38  Loss 0.505
# 		Train: 	Acc 91.67  Loss 0.325
# 		Test: 	Acc 88.27
# Epoch 055/100
# 	Batch 000/469: 	Acc 89.84  Loss 0.465
# 	Batch 100/469: 	Acc 92.19  Loss 0.342
# 	Batch 200/469: 	Acc 88.28  Loss 0.470
# 	Batch 300/469: 	Acc 88.28  Loss 0.387
# 	Batch 400/469: 	Acc 86.72  Loss 0.421
# 		Train: 	Acc 87.50  Loss 0.507
# 		Test: 	Acc 88.27
# Epoch 056/100
# 	Batch 000/469: 	Acc 91.41  Loss 0.296
# 	Batch 100/469: 	Acc 81.25  Loss 0.631
# 	Batch 200/469: 	Acc 83.59  Loss 0.615
# 	Batch 300/469: 	Acc 87.50  Loss 0.458
# 	Batch 400/469: 	Acc 82.81  Loss 0.595
# 		Train: 	Acc 87.50  Loss 0.360
# 		Test: 	Acc 88.27
# Epoch 057/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.439
# 	Batch 100/469: 	Acc 85.94  Loss 0.455
# 	Batch 200/469: 	Acc 89.06  Loss 0.376
# 	Batch 300/469: 	Acc 88.28  Loss 0.441
# 	Batch 400/469: 	Acc 89.06  Loss 0.372
# 		Train: 	Acc 87.50  Loss 0.461
# 		Test: 	Acc 88.27
# Epoch 058/100
# 	Batch 000/469: 	Acc 85.16  Loss 0.490
# 	Batch 100/469: 	Acc 89.06  Loss 0.411
# 	Batch 200/469: 	Acc 89.84  Loss 0.385
# 	Batch 300/469: 	Acc 86.72  Loss 0.416
# 	Batch 400/469: 	Acc 91.41  Loss 0.343
# 		Train: 	Acc 88.54  Loss 0.529
# 		Test: 	Acc 88.27
# Epoch 059/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.479
# 	Batch 100/469: 	Acc 87.50  Loss 0.481
# 	Batch 200/469: 	Acc 80.47  Loss 0.630
# 	Batch 300/469: 	Acc 89.06  Loss 0.405
# 	Batch 400/469: 	Acc 91.41  Loss 0.337
# 		Train: 	Acc 85.42  Loss 0.561
# 		Test: 	Acc 88.27
# Epoch 060/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.419
# 	Batch 100/469: 	Acc 89.06  Loss 0.387
# 	Batch 200/469: 	Acc 89.06  Loss 0.415
# 	Batch 300/469: 	Acc 84.38  Loss 0.580
# 	Batch 400/469: 	Acc 85.94  Loss 0.499
# 		Train: 	Acc 84.38  Loss 0.535
# 		Test: 	Acc 88.27
# Epoch 061/100
# 	Batch 000/469: 	Acc 90.62  Loss 0.364
# 	Batch 100/469: 	Acc 86.72  Loss 0.444
# 	Batch 200/469: 	Acc 89.06  Loss 0.416
# 	Batch 300/469: 	Acc 84.38  Loss 0.529
# 	Batch 400/469: 	Acc 92.97  Loss 0.377
# 		Train: 	Acc 87.50  Loss 0.473
# 		Test: 	Acc 88.27
# Epoch 062/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.450
# 	Batch 100/469: 	Acc 89.06  Loss 0.402
# 	Batch 200/469: 	Acc 88.28  Loss 0.481
# 	Batch 300/469: 	Acc 90.62  Loss 0.324
# 	Batch 400/469: 	Acc 89.06  Loss 0.373
# 		Train: 	Acc 86.46  Loss 0.404
# 		Test: 	Acc 88.27
# Epoch 063/100
# 	Batch 000/469: 	Acc 83.59  Loss 0.476
# 	Batch 100/469: 	Acc 89.06  Loss 0.361
# 	Batch 200/469: 	Acc 85.94  Loss 0.547
# 	Batch 300/469: 	Acc 88.28  Loss 0.403
# 	Batch 400/469: 	Acc 83.59  Loss 0.506
# 		Train: 	Acc 91.67  Loss 0.301
# 		Test: 	Acc 88.27
# Epoch 064/100
# 	Batch 000/469: 	Acc 90.62  Loss 0.353
# 	Batch 100/469: 	Acc 90.62  Loss 0.385
# 	Batch 200/469: 	Acc 89.06  Loss 0.403
# 	Batch 300/469: 	Acc 88.28  Loss 0.461
# 	Batch 400/469: 	Acc 88.28  Loss 0.409
# 		Train: 	Acc 83.33  Loss 0.533
# 		Test: 	Acc 88.27
# Epoch 065/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.416
# 	Batch 100/469: 	Acc 89.84  Loss 0.385
# 	Batch 200/469: 	Acc 85.16  Loss 0.495
# 	Batch 300/469: 	Acc 82.81  Loss 0.588
# 	Batch 400/469: 	Acc 86.72  Loss 0.502
# 		Train: 	Acc 88.54  Loss 0.369
# 		Test: 	Acc 88.27
# Epoch 066/100
# 	Batch 000/469: 	Acc 92.97  Loss 0.316
# 	Batch 100/469: 	Acc 87.50  Loss 0.433
# 	Batch 200/469: 	Acc 90.62  Loss 0.389
# 	Batch 300/469: 	Acc 83.59  Loss 0.599
# 	Batch 400/469: 	Acc 85.16  Loss 0.484
# 		Train: 	Acc 85.42  Loss 0.509
# 		Test: 	Acc 88.27
# Epoch 067/100
# 	Batch 000/469: 	Acc 85.16  Loss 0.631
# 	Batch 100/469: 	Acc 92.19  Loss 0.277
# 	Batch 200/469: 	Acc 87.50  Loss 0.391
# 	Batch 300/469: 	Acc 87.50  Loss 0.427
# 	Batch 400/469: 	Acc 88.28  Loss 0.426
# 		Train: 	Acc 92.71  Loss 0.256
# 		Test: 	Acc 88.27
# Epoch 068/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.458
# 	Batch 100/469: 	Acc 89.84  Loss 0.390
# 	Batch 200/469: 	Acc 88.28  Loss 0.396
# 	Batch 300/469: 	Acc 91.41  Loss 0.377
# 	Batch 400/469: 	Acc 84.38  Loss 0.531
# 		Train: 	Acc 86.46  Loss 0.503
# 		Test: 	Acc 88.27
# Epoch 069/100
# 	Batch 000/469: 	Acc 93.75  Loss 0.273
# 	Batch 100/469: 	Acc 82.03  Loss 0.570
# 	Batch 200/469: 	Acc 88.28  Loss 0.456
# 	Batch 300/469: 	Acc 92.19  Loss 0.331
# 	Batch 400/469: 	Acc 91.41  Loss 0.356
# 		Train: 	Acc 90.62  Loss 0.365
# 		Test: 	Acc 88.27
# Epoch 070/100
# 	Batch 000/469: 	Acc 89.84  Loss 0.332
# 	Batch 100/469: 	Acc 89.84  Loss 0.438
# 	Batch 200/469: 	Acc 85.16  Loss 0.453
# 	Batch 300/469: 	Acc 85.94  Loss 0.458
# 	Batch 400/469: 	Acc 92.19  Loss 0.359
# 		Train: 	Acc 86.46  Loss 0.531
# 		Test: 	Acc 88.27
# Epoch 071/100
# 	Batch 000/469: 	Acc 89.84  Loss 0.355
# 	Batch 100/469: 	Acc 87.50  Loss 0.410
# 	Batch 200/469: 	Acc 83.59  Loss 0.535
# 	Batch 300/469: 	Acc 90.62  Loss 0.377
# 	Batch 400/469: 	Acc 87.50  Loss 0.510
# 		Train: 	Acc 85.42  Loss 0.560
# 		Test: 	Acc 88.27
# Epoch 072/100
# 	Batch 000/469: 	Acc 83.59  Loss 0.579
# 	Batch 100/469: 	Acc 82.03  Loss 0.535
# 	Batch 200/469: 	Acc 89.84  Loss 0.466
# 	Batch 300/469: 	Acc 88.28  Loss 0.467
# 	Batch 400/469: 	Acc 89.84  Loss 0.460
# 		Train: 	Acc 87.50  Loss 0.438
# 		Test: 	Acc 88.27
# Epoch 073/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.441
# 	Batch 100/469: 	Acc 89.06  Loss 0.446
# 	Batch 200/469: 	Acc 84.38  Loss 0.499
# 	Batch 300/469: 	Acc 91.41  Loss 0.414
# 	Batch 400/469: 	Acc 83.59  Loss 0.537
# 		Train: 	Acc 87.50  Loss 0.471
# 		Test: 	Acc 88.27
# Epoch 074/100
# 	Batch 000/469: 	Acc 83.59  Loss 0.547
# 	Batch 100/469: 	Acc 87.50  Loss 0.488
# 	Batch 200/469: 	Acc 93.75  Loss 0.293
# 	Batch 300/469: 	Acc 85.94  Loss 0.497
# 	Batch 400/469: 	Acc 90.62  Loss 0.350
# 		Train: 	Acc 86.46  Loss 0.377
# 		Test: 	Acc 88.27
# Epoch 075/100
# 	Batch 000/469: 	Acc 89.84  Loss 0.372
# 	Batch 100/469: 	Acc 93.75  Loss 0.268
# 	Batch 200/469: 	Acc 89.84  Loss 0.389
# 	Batch 300/469: 	Acc 83.59  Loss 0.471
# 	Batch 400/469: 	Acc 86.72  Loss 0.474
# 		Train: 	Acc 88.54  Loss 0.432
# 		Test: 	Acc 88.27
# Epoch 076/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.431
# 	Batch 100/469: 	Acc 89.84  Loss 0.362
# 	Batch 200/469: 	Acc 92.97  Loss 0.273
# 	Batch 300/469: 	Acc 85.94  Loss 0.445
# 	Batch 400/469: 	Acc 87.50  Loss 0.482
# 		Train: 	Acc 85.42  Loss 0.560
# 		Test: 	Acc 88.27
# Epoch 077/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.452
# 	Batch 100/469: 	Acc 92.19  Loss 0.355
# 	Batch 200/469: 	Acc 87.50  Loss 0.483
# 	Batch 300/469: 	Acc 86.72  Loss 0.516
# 	Batch 400/469: 	Acc 82.03  Loss 0.481
# 		Train: 	Acc 89.58  Loss 0.459
# 		Test: 	Acc 88.27
# Epoch 078/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.419
# 	Batch 100/469: 	Acc 92.19  Loss 0.296
# 	Batch 200/469: 	Acc 84.38  Loss 0.541
# 	Batch 300/469: 	Acc 89.84  Loss 0.364
# 	Batch 400/469: 	Acc 92.19  Loss 0.350
# 		Train: 	Acc 91.67  Loss 0.393
# 		Test: 	Acc 88.27
# Epoch 079/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.521
# 	Batch 100/469: 	Acc 90.62  Loss 0.397
# 	Batch 200/469: 	Acc 83.59  Loss 0.518
# 	Batch 300/469: 	Acc 92.19  Loss 0.337
# 	Batch 400/469: 	Acc 86.72  Loss 0.452
# 		Train: 	Acc 86.46  Loss 0.523
# 		Test: 	Acc 88.27
# Epoch 080/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.465
# 	Batch 100/469: 	Acc 87.50  Loss 0.465
# 	Batch 200/469: 	Acc 93.75  Loss 0.267
# 	Batch 300/469: 	Acc 84.38  Loss 0.498
# 	Batch 400/469: 	Acc 90.62  Loss 0.455
# 		Train: 	Acc 93.75  Loss 0.290
# 		Test: 	Acc 88.27
# Epoch 081/100
# 	Batch 000/469: 	Acc 92.97  Loss 0.333
# 	Batch 100/469: 	Acc 87.50  Loss 0.444
# 	Batch 200/469: 	Acc 81.25  Loss 0.566
# 	Batch 300/469: 	Acc 84.38  Loss 0.490
# 	Batch 400/469: 	Acc 86.72  Loss 0.486
# 		Train: 	Acc 88.54  Loss 0.414
# 		Test: 	Acc 88.27
# Epoch 082/100
# 	Batch 000/469: 	Acc 92.97  Loss 0.366
# 	Batch 100/469: 	Acc 84.38  Loss 0.536
# 	Batch 200/469: 	Acc 83.59  Loss 0.470
# 	Batch 300/469: 	Acc 85.94  Loss 0.440
# 	Batch 400/469: 	Acc 87.50  Loss 0.500
# 		Train: 	Acc 85.42  Loss 0.562
# 		Test: 	Acc 88.27
# Epoch 083/100
# 	Batch 000/469: 	Acc 82.81  Loss 0.566
# 	Batch 100/469: 	Acc 85.94  Loss 0.465
# 	Batch 200/469: 	Acc 85.16  Loss 0.482
# 	Batch 300/469: 	Acc 89.06  Loss 0.464
# 	Batch 400/469: 	Acc 87.50  Loss 0.455
# 		Train: 	Acc 82.29  Loss 0.634
# 		Test: 	Acc 88.27
# Epoch 084/100
# 	Batch 000/469: 	Acc 90.62  Loss 0.361
# 	Batch 100/469: 	Acc 85.94  Loss 0.452
# 	Batch 200/469: 	Acc 87.50  Loss 0.426
# 	Batch 300/469: 	Acc 90.62  Loss 0.352
# 	Batch 400/469: 	Acc 85.16  Loss 0.572
# 		Train: 	Acc 82.29  Loss 0.528
# 		Test: 	Acc 88.27
# Epoch 085/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.463
# 	Batch 100/469: 	Acc 87.50  Loss 0.387
# 	Batch 200/469: 	Acc 92.19  Loss 0.312
# 	Batch 300/469: 	Acc 91.41  Loss 0.356
# 	Batch 400/469: 	Acc 92.97  Loss 0.352
# 		Train: 	Acc 91.67  Loss 0.352
# 		Test: 	Acc 88.27
# Epoch 086/100
# 	Batch 000/469: 	Acc 86.72  Loss 0.460
# 	Batch 100/469: 	Acc 81.25  Loss 0.519
# 	Batch 200/469: 	Acc 89.84  Loss 0.340
# 	Batch 300/469: 	Acc 87.50  Loss 0.528
# 	Batch 400/469: 	Acc 85.16  Loss 0.489
# 		Train: 	Acc 89.58  Loss 0.382
# 		Test: 	Acc 88.27
# Epoch 087/100
# 	Batch 000/469: 	Acc 85.94  Loss 0.450
# 	Batch 100/469: 	Acc 90.62  Loss 0.414
# 	Batch 200/469: 	Acc 88.28  Loss 0.485
# 	Batch 300/469: 	Acc 91.41  Loss 0.370
# 	Batch 400/469: 	Acc 85.94  Loss 0.503
# 		Train: 	Acc 90.62  Loss 0.361
# 		Test: 	Acc 88.27
# Epoch 088/100
# 	Batch 000/469: 	Acc 85.16  Loss 0.514
# 	Batch 100/469: 	Acc 89.84  Loss 0.513
# 	Batch 200/469: 	Acc 92.19  Loss 0.321
# 	Batch 300/469: 	Acc 89.06  Loss 0.443
# 	Batch 400/469: 	Acc 85.94  Loss 0.493
# 		Train: 	Acc 82.29  Loss 0.578
# 		Test: 	Acc 88.27
# Epoch 089/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.505
# 	Batch 100/469: 	Acc 89.06  Loss 0.371
# 	Batch 200/469: 	Acc 87.50  Loss 0.437
# 	Batch 300/469: 	Acc 91.41  Loss 0.340
# 	Batch 400/469: 	Acc 88.28  Loss 0.438
# 		Train: 	Acc 81.25  Loss 0.631
# 		Test: 	Acc 88.27
# Epoch 090/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.469
# 	Batch 100/469: 	Acc 85.94  Loss 0.485
# 	Batch 200/469: 	Acc 84.38  Loss 0.583
# 	Batch 300/469: 	Acc 85.94  Loss 0.414
# 	Batch 400/469: 	Acc 82.81  Loss 0.538
# 		Train: 	Acc 88.54  Loss 0.378
# 		Test: 	Acc 88.27
# Epoch 091/100
# 	Batch 000/469: 	Acc 85.16  Loss 0.512
# 	Batch 100/469: 	Acc 89.06  Loss 0.439
# 	Batch 200/469: 	Acc 87.50  Loss 0.487
# 	Batch 300/469: 	Acc 87.50  Loss 0.372
# 	Batch 400/469: 	Acc 88.28  Loss 0.403
# 		Train: 	Acc 91.67  Loss 0.377
# 		Test: 	Acc 88.27
# Epoch 092/100
# 	Batch 000/469: 	Acc 87.50  Loss 0.409
# 	Batch 100/469: 	Acc 91.41  Loss 0.321
# 	Batch 200/469: 	Acc 85.16  Loss 0.554
# 	Batch 300/469: 	Acc 88.28  Loss 0.482
# 	Batch 400/469: 	Acc 88.28  Loss 0.404
# 		Train: 	Acc 85.42  Loss 0.527
# 		Test: 	Acc 88.27
# Epoch 093/100
# 	Batch 000/469: 	Acc 85.16  Loss 0.507
# 	Batch 100/469: 	Acc 89.06  Loss 0.378
# 	Batch 200/469: 	Acc 87.50  Loss 0.488
# 	Batch 300/469: 	Acc 88.28  Loss 0.412
# 	Batch 400/469: 	Acc 91.41  Loss 0.369
# 		Train: 	Acc 89.58  Loss 0.400
# 		Test: 	Acc 88.27
# Epoch 094/100
# 	Batch 000/469: 	Acc 88.28  Loss 0.482
# 	Batch 100/469: 	Acc 85.94  Loss 0.492
# 	Batch 200/469: 	Acc 91.41  Loss 0.348
# 	Batch 300/469: 	Acc 90.62  Loss 0.363
# 	Batch 400/469: 	Acc 86.72  Loss 0.463
# 		Train: 	Acc 87.50  Loss 0.483
# 		Test: 	Acc 88.27
# Epoch 095/100
# 	Batch 000/469: 	Acc 92.97  Loss 0.317
# 	Batch 100/469: 	Acc 92.19  Loss 0.332
# 	Batch 200/469: 	Acc 88.28  Loss 0.391
# 	Batch 300/469: 	Acc 92.19  Loss 0.330
# 	Batch 400/469: 	Acc 85.94  Loss 0.470
# 		Train: 	Acc 86.46  Loss 0.464
# 		Test: 	Acc 88.27
# Epoch 096/100
# 	Batch 000/469: 	Acc 85.16  Loss 0.593
# 	Batch 100/469: 	Acc 91.41  Loss 0.349
# 	Batch 200/469: 	Acc 92.97  Loss 0.302
# 	Batch 300/469: 	Acc 85.16  Loss 0.488
# 	Batch 400/469: 	Acc 87.50  Loss 0.502
# 		Train: 	Acc 87.50  Loss 0.442
# 		Test: 	Acc 88.27
# Epoch 097/100
# 	Batch 000/469: 	Acc 89.06  Loss 0.386
# 	Batch 100/469: 	Acc 89.84  Loss 0.395
# 	Batch 200/469: 	Acc 86.72  Loss 0.526
# 	Batch 300/469: 	Acc 88.28  Loss 0.405
# 	Batch 400/469: 	Acc 85.16  Loss 0.491
# 		Train: 	Acc 91.67  Loss 0.311
# 		Test: 	Acc 88.27
# Epoch 098/100
# 	Batch 000/469: 	Acc 89.84  Loss 0.418
# 	Batch 100/469: 	Acc 92.19  Loss 0.300
# 	Batch 200/469: 	Acc 85.94  Loss 0.405
# 	Batch 300/469: 	Acc 86.72  Loss 0.385
# 	Batch 400/469: 	Acc 90.62  Loss 0.378
# 		Train: 	Acc 87.50  Loss 0.527
# 		Test: 	Acc 88.27
# Epoch 099/100
# 	Batch 000/469: 	Acc 91.41  Loss 0.377
# 	Batch 100/469: 	Acc 89.06  Loss 0.416
# 	Batch 200/469: 	Acc 87.50  Loss 0.440
# 	Batch 300/469: 	Acc 87.50  Loss 0.464
# 	Batch 400/469: 	Acc 88.28  Loss 0.416
# 		Train: 	Acc 88.54  Loss 0.491
# 		Test: 	Acc 88.27
